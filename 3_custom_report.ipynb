# %%
from sapiopylib.rest.User import SapioUser
from sapiopylib.rest.DataMgmtService import DataMgmtServer
from sapiopylib.rest.pojo.CustomReport import *
from IPython.display import display, HTML
import pandas as pd
pd.set_option('display.max_columns', 100)

user = SapioUser(url="https://linux-vm:8443/webservice/api",
                 guid="60916c2e-fe12-4d71-b7e6-f5a9e9b4d282", account_name="sapio",
                 username="pyRestTest", password="password1", verify_ssl_cert=False)
customReportManager = DataMgmtServer.get_custom_report_manager(user)

# %% [markdown]
# Custom Report API offers a way for users to send complex queries about data records across a hierarchy.
#
# In the first example, we will run a quick report, which is consisted with only a single term about a data record.
# We will find all samples with sample type 'Blood' in the system, but only for the first 100 samples in the system.
#
# We can obtain the data frame from report result so it can be organized as pandas data frame and display it.

# %%
root_term = RawReportTerm('Sample', 'ExemplarSampleType', RawTermOperation.EQUAL_TO_OPERATOR, 'Blood', is_negated=True)
report = customReportManager.run_quick_report(root_term, page_size=100)
data_frame = report.get_data_frame()
display(data_frame)
# Out:
# /home/yqiao/anaconda3/envs/RDKit/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'linux-vm'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#    Sample.ObservedCondition Sample.MultiParentLink234  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                      ...                       ...
# 71                                               None
# 72                                               None
# 73                                               None
# 74                                               None
# 75                                               None
#
#                                  Sample.OtherSampleId Sample.ActiveWorkflowId  \
# 0                                                                        None
# 1                                                                        None
# 2                                                                        None
# 3   export_COVID19 samples 23_04_20_ST3_COVID19_IC...                    None
# 4                                                                        None
# ..                                                ...                     ...
# 71                                                                       None
# 72                                                                       None
# 73                                                                       None
# 74                                                                       None
# 75                                                                       None
#
#    Sample.RelatedNotebookExperiment Sample.SacrificedDate  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ..                              ...                   ...
# 71                                                   None
# 72                                                   None
# 73                                                   None
# 74                                                   None
# 75                                                   None
#
#    Sample.RelatedRecord170 Sample.SampleId Sample.StorageLocationBarcode  \
# 0                                   000004
# 1                                   000005
# 2                                   000006
# 3                                   000007
# 4                             PyWebDemo-13
# ..                     ...             ...                           ...
# 71                            PyWebDemo-86
# 72                            PyWebDemo-87
# 73                            PyWebDemo-88
# 74                            PyWebDemo-91
# 75                            PyWebDemo-92
#
#    Sample.Organism Sample.CreatedBy Sample.CollectionDateTime  \
# 0                           sdmsapi                      None
# 1                           sdmsapi                      None
# 2                           sdmsapi                      None
# 3                           sdmsapi                      None
# 4                        pyRestTest                      None
# ..             ...              ...                       ...
# 71                       pyRestTest                      None
# 72                       pyRestTest                      None
# 73                       pyRestTest                      None
# 74                       pyRestTest                      None
# 75                       pyRestTest                      None
#
#    Sample.RelatedRecord146 Sample.ElnbNumber Sample.PercentRecoveries  \
# 0                                                                None
# 1                                                                None
# 2                                                                None
# 3                                                                None
# 4                                                                None
# ..                     ...               ...                      ...
# 71                                                               None
# 72                                                               None
# 73                                                               None
# 74                                                               None
# 75                                                               None
#
#                                 Sample.DataRecordName Sample.Volume  \
# 0                                              000004          None
# 1                                              000005          None
# 2                                              000006          None
# 3   000007 export_COVID19 samples 23_04_20_ST3_COV...          None
# 4                                        PyWebDemo-13          None
# ..                                                ...           ...
# 71                                       PyWebDemo-86          None
# 72                                       PyWebDemo-87          None
# 73                                       PyWebDemo-88          None
# 74                                       PyWebDemo-91          None
# 75                                       PyWebDemo-92          None
#
#    Sample.ExemplarSampleType Sample.RelatedChild123 Sample.ControlType  \
# 0                                              None
# 1                                              None
# 2             Flow Cytometry                   None
# 3             Flow Cytometry                   None
# 4                                              None
# ..                       ...                    ...                ...
# 71                                             None
# 72                                             None
# 73                                             None
# 74                                             None
# 75                                             None
#
#    Sample.RelatedRecord181 Sample.TotalMass Sample.ConcentrationUnits  \
# 0                                      None                     ng/uL
# 1                                      None                     ng/uL
# 2                                      None                     ng/uL
# 3                                      None                     ng/uL
# 4                                      None                     ng/uL
# ..                     ...              ...                       ...
# 71                                     None                     ng/uL
# 72                                     None                     ng/uL
# 73                                     None                     ng/uL
# 74                                     None                     ng/uL
# 75                                     None                     ng/uL
#
#    Sample.RelatedRecord180 Sample.CollectionDate Sample.RelatedRecord112  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# ..                     ...                   ...                     ...
# 71                                          None
# 72                                          None
# 73                                          None
# 74                                          None
# 75                                          None
#
#    Sample.RelatedRecord111 Sample.RelatedRecord199 Sample.RelatedRecord110  \
# 0
# 1
# 2
# 3
# 4
# ..                     ...                     ...                     ...
# 71
# 72
# 73
# 74
# 75
#
#     Sample.DateCreated Sample.MultiParentLink176 Sample.RelatedRecord119  \
# 0        1663688244010                      None
# 1        1663688248670                      None
# 2        1663688707312                      None
# 3        1663693730249                      None
# 4        1663881353164                      None
# ..                 ...                       ...                     ...
# 71       1665080039042                      None
# 72       1665080039042                      None
# 73       1665080039042                      None
# 74       1665080693958                      None
# 75       1665080693958                      None
#
#    Sample.RowPosition Sample.ColPosition Sample.VeloxLastModifiedBy  \
# 0                                                           sdmsapi
# 1                                                           sdmsapi
# 2                                                           sdmsapi
# 3                                                           sdmsapi
# 4                                                        pyRestTest
# ..                ...                ...                        ...
# 71                                                       pyRestTest
# 72                                                       pyRestTest
# 73                                                       pyRestTest
# 74                                                       pyRestTest
# 75                                                       pyRestTest
#
#     Sample.RecordId Sample.ExemplarSampleStatus Sample.MultiParentLink247  \
# 0               130                                                  None
# 1               132                                                  None
# 2               169                                                  None
# 3               171                                                  None
# 4               219                                                  None
# ..              ...                         ...                       ...
# 71              400                                                  None
# 72              401                                                  None
# 73              402                                                  None
# 74              409                                                  None
# 75              410                                                  None
#
#    Sample.VolumeUnits Sample.RelatedRecord168 Sample.RelatedRecord200  \
# 0
# 1
# 2
# 3
# 4                                                                   7
# ..                ...                     ...                     ...
# 71
# 72
# 73
# 74                                                                 89
# 75                                                                 90
#
#    Sample.Comments Sample.ContainerType Sample.PreviousExemplarStatus  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                           ...
# 71
# 72
# 73
# 74
# 75
#
#    Sample.TimePoint Sample.Concentration Sample.Flags Sample.RelatedPlate  \
# 0              None                 None
# 1              None                 None
# 2              None                 None
# 3              None                 None
# 4              None                 None
# ..              ...                  ...          ...                 ...
# 71             None                 None
# 72             None                 None
# 73             None                 None
# 74             None                 None
# 75             None                 None
#
#    Sample.MultiParentLink243 Sample.RelatedRecord208 Sample.StorageUnitPath  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...                     ...                    ...
# 71                      None
# 72                      None
# 73                      None
# 74                      None
# 75                      None
#
#    Sample.SapioSingleTemplateProcess Sample.LastEditedBy  \
# 0
# 1
# 2
# 3
# 4
# ..                               ...                 ...
# 71
# 72
# 73
# 74
# 75
#
#     Sample.VeloxLastModifiedDate Sample.PlateId Sample.RelatedChild149  \
# 0                  1663688244522                                  None
# 1                  1663688248737                                  None
# 2                  1663688707708                                  None
# 3                  1663693730582                                  None
# 4                  1663881353236                                  None
# ..                           ...            ...                    ...
# 71                 1665080039468                                  None
# 72                 1665080039468                                  None
# 73                 1665080039468                                  None
# 74                 1665080694292                                  None
# 75                 1665080694481                                  None
#
#     Sample.IsInvalid
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 71             False
# 72             False
# 73             False
# 74             False
# 75             False
#
# [76 rows x 57 columns]

# %% [markdown]
# In a more advanced report, you may want to enter multiple conditions, across a hierarchy of records.
# Here's a way to get all attachments under a location '205 N George St'

# %%
term1 = RawReportTerm('VeloxLocation', 'LocationName', RawTermOperation.EQUAL_TO_OPERATOR, '205 N George St')
term2 = RawReportTerm('Attachment', 'RecordId', RawTermOperation.GREATER_THAN_OR_EQUAL_OPERATOR, '0')
root_term = CompositeReportTerm(term1, CompositeTermOperation.AND_OPERATOR, term2)
column_list = [ReportColumn('Attachment', 'FilePath', FieldType.STRING), ReportColumn('Attachment', 'RecordId', FieldType.LONG)]
request = CustomReportCriteria(column_list, root_term)
report = customReportManager.run_custom_report(request)
data_frame = report.get_data_frame()
display(data_frame)
# Out:
# /home/yqiao/anaconda3/envs/RDKit/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'linux-vm'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#               Attachment.FilePath  Attachment.RecordId
# 0  2360814_166058953148747601.pdf                  111
# 1                         Est.pdf                  112
# 2           Sapio Mutual NDA.docx                  116
